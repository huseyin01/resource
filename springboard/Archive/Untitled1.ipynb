# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
ri=pd.read_csv('police.csv')

# %%
ri.head()
# Out:
#     stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0  2005-01-02     01:55          NaN             M          1985.0
# 1  2005-01-18     08:15          NaN             M          1965.0
# 2  2005-01-23     23:15          NaN             M          1972.0
# 3  2005-02-20     17:15          NaN             M          1986.0
# 4  2005-03-14     10:00          NaN             F          1984.0
#
#    driver_age driver_race     violation_raw violation  search_conducted  \
# 0        20.0       White          Speeding  Speeding             False
# 1        40.0       White          Speeding  Speeding             False
# 2        33.0       White          Speeding  Speeding             False
# 3        19.0       White  Call for Service     Other             False
# 4        21.0       White          Speeding  Speeding             False
#
#   search_type   stop_outcome is_arrested stop_duration  drugs_related_stop
# ...

# %%
ri.shape
# Out:
# (91741, 15)

# %%
ri.describe()
# Out:
#        county_name  driver_age_raw    driver_age
# count          0.0    86414.000000  86120.000000
# mean           NaN     1970.491228     34.011333
# std            NaN      110.914909     12.738564
# min            NaN        0.000000     15.000000
# 25%            NaN     1967.000000     23.000000
# 50%            NaN     1980.000000     31.000000
# 75%            NaN     1987.000000     43.000000
# max            NaN     8801.000000     99.000000

# %%
ri.tail()
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 91736  2015-12-31     20:27          NaN             M          1986.0
# 91737  2015-12-31     20:35          NaN             F          1982.0
# 91738  2015-12-31     20:45          NaN             M          1992.0
# 91739  2015-12-31     21:42          NaN             M          1993.0
# 91740  2015-12-31     22:46          NaN             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# 91736        29.0       White                        Speeding
# 91737        33.0       White  Equipment/Inspection Violation
# 91738        23.0       White         Other Traffic Violation
# 91739        22.0       White                        Speeding
# 91740        56.0    Hispanic                        Speeding
#
#               violation  search_conducted search_type stop_outcome  \
# 91736          Speeding             False         NaN      Warning
# ...

# %%
ri.isnull().sum()
# Out:
# stop_date                 0
# stop_time                 0
# county_name           91741
# driver_gender          5335
# driver_age_raw         5327
# driver_age             5621
# driver_race            5333
# violation_raw          5333
# violation              5333
# search_conducted          0
# search_type           88545
# stop_outcome           5333
# is_arrested            5333
# stop_duration          5333
# drugs_related_stop        0
# dtype: int64

# %%
ri.drop('county_name', axis=1, inplace=True)
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0      2005-01-02     01:55             M          1985.0        20.0
# 1      2005-01-18     08:15             M          1965.0        40.0
# 2      2005-01-23     23:15             M          1972.0        33.0
# 3      2005-02-20     17:15             M          1986.0        19.0
# 4      2005-03-14     10:00             F          1984.0        21.0
# 5      2005-03-23     09:45             M          1982.0        23.0
# 6      2005-04-01     17:30             M          1969.0        36.0
# 7      2005-06-06     13:20             F          1986.0        19.0
# 8      2005-07-13     10:15             M          1970.0        35.0
# 9      2005-07-13     15:45             M          1970.0        35.0
# 10     2005-07-13     16:20             M          1979.0        26.0
# 11     2005-07-13     19:00             F          1966.0        39.0
# ...

# %%
ri.columns
# Out:
# Index(['stop_date', 'stop_time', 'county_name', 'driver_gender',
#        'driver_age_raw', 'driver_age', 'driver_race', 'violation_raw',
#        'violation', 'search_conducted', 'search_type', 'stop_outcome',
#        'is_arrested', 'stop_duration', 'drugs_related_stop'],
#       dtype='object')

# %%
ri[ri['violation']=='Speeding'].driver_gender.value_counts()
# Out:
# M    32979
# F    15482
# Name: driver_gender, dtype: int64

# %%
df = pd.read_csv('https://query.data.world/s/e6ktfojmmwoczxfdmqmid2gvyntdo6')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa8 in position 7: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-18-fade401916c5> in <module>()
# ----> 1 df = pd.read_csv('https://query.data.world/s/e6ktfojmmwoczxfdmqmid2gvyntdo6')
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('https://query.data.world/s/e6ktfojmmwoczxfdmqmid2gvyntdo6')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa8 in position 7: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-20-fade401916c5> in <module>()
# ----> 1 df = pd.read_csv('https://query.data.world/s/e6ktfojmmwoczxfdmqmid2gvyntdo6')
#
# ...

# %%
pwd
# Out:
# '/Users/onlyone/Documents/Springboard'

# %%
cd Downloads
# Out:
# [Errno 2] No such file or directory: 'Downloads'
# /Users/onlyone/Documents/Springboard

# %%
..
# Out:
#   File "<ipython-input-23-3d80792ead7e>", line 1
#     ..
#     ^
# SyntaxError: invalid syntax

# %%
cd ..
# Out:
# /Users/onlyone/Documents

# %%
cd ..
# Out:
# /Users/onlyone

# %%
cd Downloads
# Out:
# /Users/onlyone/Downloads

# %%
df = pd.read_csv("gtd1993_748.csv", mode='r')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-23ff0ac28789> in <module>()
# ----> 1 df = pd.read_csv("gtd1993_748.csv", mode='r')
#
# TypeError: parser_f() got an unexpected keyword argument 'mode'

# %%
ls
# Out:
# 56C7EB461724646F9202EF913F7D8528803E582783EE5D8F77A77286016BF42677785AA084A7CE07CC081224B00C33AF.pdf
# 9781461409526-c1.pdf
# AYSE TAS (1).docx
# AYSE TAS.docx
# CV_Huseyin YILMAZ.docx
# GitHub Desktop.app/
# Kings/
# RESUME Mehmet Umut CAKIR 2018.docx
# TIV-Export-Top-50-2000-2017.csv
# ch1_slides.pdf
# ch2_slides.pdf
# ch3_slides.pdf
# ch4_slides.pdf
# chapter5.pdf
# ehliyet/
# gtd1993_748.csv
# pep8.pdf
# pycon-2018-tutorial-master/

# %%
gtd1993_748.csv
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-36cf90062be2> in <module>()
# ----> 1 gtd1993_748.csv
#
# NameError: name 'gtd1993_748' is not defined

# %%
gtd1993_748.csv/
# Out:
#   File "<ipython-input-31-9259eb071e25>", line 1
#     gtd1993_748.csv/
#                     ^
# SyntaxError: invalid syntax

# %%
/gtd1993_748.csv
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-1915fe262b10> in <module>()
# ----> 1 gtd1993_748.csv()
#
# NameError: name 'gtd1993_748' is not defined

# %%
AYSE TAS.docx
# Out:
#   File "<ipython-input-33-625969166a5f>", line 1
#     AYSE TAS.docx
#            ^
# SyntaxError: invalid syntax

# %%
/AYSE TAS.docx
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-d998f0427948> in <module>()
# ----> 1 AYSE(TAS.docx)
#
# NameError: name 'AYSE' is not defined

# %%
"AYSE TAS.docx"
# Out:
# 'AYSE TAS.docx'

# %%
cd ..
# Out:
# /Users/onlyone

# %%
documents
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-22162c9c5638> in <module>()
# ----> 1 documents
#
# NameError: name 'documents' is not defined

# %%
Documents
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-011d9571709b> in <module>()
# ----> 1 Documents
#
# NameError: name 'Documents' is not defined

# %%
ls
# Out:
# Applications/           Movies/                 anaconda3/
# Desktop/                Music/                  deneme_1.ipynb
# Documents/              Pictures/               iCloud Drive (Archive)/
# Downloads/              Public/                 newwnew/
# Library/                Untitled.ipynb

# %%
cd Documents
# Out:
# /Users/onlyone/Documents

# %%
cd data
# Out:
# /Users/onlyone/Documents/data

# %%
ls
# Out:
# chipotle.tsv.html       imdb_1000.csv.html      titanic_train.csv.html
# drinks.csv.html         titanic.csv
# gtd1993_748.csv         titanic_test.csv.html

# %%
q = pd.read_csv('gtd1993_748.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa8 in position 7: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-43-a5e6a700dcdc> in <module>()
# ----> 1 q = pd.read_csv('gtd1993_748.csv')
#
# ...
